# %% [markdown]
# # Notebook for running VLMs

# %% [markdown]
# Use this notebook to run VLMs using SINTEF's Ollama API keys.

# %% [markdown]
# Choose a model from the following list:
# - gpt-oss:120b
# - gpt-oss:20b
# - qwen3:235b
# - qwen3-vl:235b
# - qwen3-vl:32b
# - qwen3-vl:8b
# - qwen3-vl:4b
# - qwen3-vl:2b
# - gemma3:27b-it-qat
# - gemma3:4b
# - phi4:14b
# - MichelRosselli/GLM-4.6:Q4_K_M
# - hf.co/NorwAI/NorwAI-Magistral-24B-reasoning:Q8_0
# - mistral-small3.2:latest
# - hf.co/norallm/normistral-7b-warm-instruct:Q8_0
# - deepseek-r1:70b-llama-distill-q8_0
# - embeddinggemma:latest
# - nomic-embed-text:latest

# %%
#example
message = "are each of these images pro-Ukraine or pro-Russia?"
model = "gemma3:4b"
images=["small_datasets/dataset_1/images/588_FUI_AgADE60xGym0nFM|dan_dnr.jpg", "small_datasets/dataset_2/images/11648_FUI_AgADGM4xG1SJqUo|kharkov_trempel.jpg"]
from ollama import Client
client = Client(
    host="https://ollama.sct.sintef.no",
    headers={"Authorization": "Bearer BAEX4eMGSA4iIEmPL3BrMMBhSM3IOWms"})
response = client.chat(
    model=model,
    messages=[{"role":"user","content":message,"images":images}],
)
print(response.message.content)
# Out:
# Here's an analysis of each image regarding its potential political leaning:
#
# **Image 1:**
#
# *   **Content:** This image shows a man in a camouflage uniform with the insignia of the "Donetsk People's Republic" (DPR) prominently displayed on his shoulder. This is a separatist entity that declared independence with Russia's support. The arm patch also displays the letters "С Д К К".
# *   **Interpretation:** This image is definitively **pro-Russia** or at least aligned with the separatist forces in the Donbas region. It's a clear demonstration of support for a Russia-backed entity.
#
# **Image 2:**
#
# *   **Content:** This image shows a shell near the Ukrainian national police emblem.
# *   **Interpretation:** This image is definitively **pro-Ukraine**. It uses the national symbol to show support.
#
# ...
